# %% [markdown]
# #### Repaso de diccionarios

# %%
nuc = {'a':'t', 'c':'g', 'g':'c', 't':'a'}

# %%
nuc
# Out:
# {'a': 't', 'c': 'g', 'g': 'c', 't': 'a'}

# %%
# sacar las claves de un diccionario
list(nuc.keys())
# Out:
# ['a', 'c', 'g', 't']

# %%
# sacar los valores de un diccionario
list(nuc.values())
# Out:
# ['t', 'g', 'c', 'a']

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <font color = royalblue>Sesión 2 (5 horas)</font>
#
# ## TÉCNICAS DE VISUALIZACIÓN DE DATOS
#
#     DataFrame (pandas).
#     Integración de estructuras.
#     Visualizaciones básicas con Matplotlib.
#     Visualizaciones básicas con Seaborn.
#     Gráficos personalizados para publicaciones.

# %% [markdown]
# #### instalaciones de:
#
# * pandas
# * itables
# * numpy
# * matplotlib
#
# Comando para instalar paquetes
# `python -mpip install pandas`

# %% [markdown]
# # <font color = royalblue>DataFrame (Pandas).</font>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_iris.txt', sep = '\t')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %% [markdown]
# ## <font color = red>Ejercicio</font>
# * #### Conocer el número de columnas
# * #### seleccionar columnas
# * #### seleccionar filas
# * #### rangos de numeros
# * #### alimiar columnas
# * #### agregar columnas
# * #### convertir una columna en lista
# * #### Remover duplicados

# %% [markdown]
# #### Conocer el número de columnas

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species',
#        'species_id'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 6

# %% [markdown]
# #### seleccionar columnas

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df[['sepal_length', 'species']]
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 2             4.7     setosa
# 3             4.6     setosa
# 4             5.0     setosa
# ..            ...        ...
# 145           6.7  virginica
# 146           6.3  virginica
# 147           6.5  virginica
# 148           6.2  virginica
# 149           5.9  virginica
#
# [150 rows x 2 columns]

# %% [markdown]
# #### Remover duplicados

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df['species'].drop_duplicates()
# Out:
# 0          setosa
# 50     versicolor
# 100     virginica
# Name: species, dtype: object

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
set(df.species.tolist())
# Out:
# {'setosa', 'versicolor', 'virginica'}

# %% [markdown]
# #### seleccionar filas

# %%
df[df['species'] == 'versicolor']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species  \
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# 63           6.1          2.9           4.7          1.4  versicolor
# 64           5.6          2.9           3.6          1.3  versicolor
# 65           6.7          3.1           4.4          1.4  versicolor
# 66           5.6          3.0           4.5          1.5  versicolor
# 67           5.8          2.7           4.1          1.0  versicolor
# 68           6.2          2.2           4.5          1.5  versicolor
# 69           5.6          2.5           3.9          1.1  versicolor
# 70           5.9          3.2           4.8          1.8  versicolor
# 71           6.1          2.8           4.0          1.3  versicolor
# 72           6.3          2.5           4.9          1.5  versicolor
# 73           6.1          2.8           4.7          1.2  versicolor
# 74           6.4          2.9           4.3          1.3  versicolor
# 75           6.6          3.0           4.4          1.4  versicolor
# 76           6.8          2.8           4.8          1.4  versicolor
# 77           6.7          3.0           5.0          1.7  versicolor
# 78           6.0          2.9           4.5          1.5  versicolor
# 79           5.7          2.6           3.5          1.0  versicolor
# 80           5.5          2.4           3.8          1.1  versicolor
# 81           5.5          2.4           3.7          1.0  versicolor
# 82           5.8          2.7           3.9          1.2  versicolor
# 83           6.0          2.7           5.1          1.6  versicolor
# 84           5.4          3.0           4.5          1.5  versicolor
# 85           6.0          3.4           4.5          1.6  versicolor
# 86           6.7          3.1           4.7          1.5  versicolor
# 87           6.3          2.3           4.4          1.3  versicolor
# 88           5.6          3.0           4.1          1.3  versicolor
# 89           5.5          2.5           4.0          1.3  versicolor
# 90           5.5          2.6           4.4          1.2  versicolor
# 91           6.1          3.0           4.6          1.4  versicolor
# 92           5.8          2.6           4.0          1.2  versicolor
# 93           5.0          2.3           3.3          1.0  versicolor
# 94           5.6          2.7           4.2          1.3  versicolor
# 95           5.7          3.0           4.2          1.2  versicolor
# 96           5.7          2.9           4.2          1.3  versicolor
# 97           6.2          2.9           4.3          1.3  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
# 99           5.7          2.8           4.1          1.3  versicolor
#
#     species_id
# 50           2
# 51           2
# 52           2
# 53           2
# 54           2
# 55           2
# 56           2
# 57           2
# 58           2
# 59           2
# 60           2
# 61           2
# 62           2
# 63           2
# 64           2
# 65           2
# 66           2
# 67           2
# 68           2
# 69           2
# 70           2
# 71           2
# 72           2
# 73           2
# 74           2
# 75           2
# 76           2
# 77           2
# 78           2
# 79           2
# 80           2
# 81           2
# 82           2
# 83           2
# 84           2
# 85           2
# 86           2
# 87           2
# 88           2
# 89           2
# 90           2
# 91           2
# 92           2
# 93           2
# 94           2
# 95           2
# 96           2
# 97           2
# 98           2
# 99           2

# %% [markdown]
# #### rangos de numeros

# %%
df1 = df[(df['sepal_length'] >= 4.5) & (df['sepal_length'] <=5.5)]

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  species_id
# count     55.000000    55.000000     55.000000    55.000000   55.000000
# mean       5.065455     3.203636      1.992727     0.458182    1.236364
# std        0.277033     0.508798      1.012305     0.428473    0.469974
# min        4.500000     2.000000      1.000000     0.100000    1.000000
# 25%        4.900000     3.000000      1.400000     0.200000    1.000000
# 50%        5.000000     3.300000      1.500000     0.200000    1.000000
# 75%        5.250000     3.500000      1.800000     0.450000    1.000000
# max        5.500000     4.200000      4.500000     1.700000    3.000000

# %%
set(df.species.tolist())
# Out:
# {'setosa', 'versicolor', 'virginica'}

# %%
df[df['species'].str.contains('.a') == True]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [100 rows x 6 columns]

# %%
df[df['sepal_length'] == 4.5]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species  species_id
# 41           4.5          2.3           1.3          0.3  setosa           1

# %% [markdown]
# #### alimiar columnas

# %%
df = df.drop(columns = ['species'])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species_id
# 0             5.1          3.5           1.4          0.2           1
# 1             4.9          3.0           1.4          0.2           1
# 2             4.7          3.2           1.3          0.2           1
# 3             4.6          3.1           1.5          0.2           1
# 4             5.0          3.6           1.4          0.2           1
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3           3
# 146           6.3          2.5           5.0          1.9           3
# 147           6.5          3.0           5.2          2.0           3
# 148           6.2          3.4           5.4          2.3           3
# 149           5.9          3.0           5.1          1.8           3
#
# [150 rows x 5 columns]

# %%
esp = dict(zip([1, 2, 3], ['setosa', 'versicolor', 'virginica']))

# %%
esp
# Out:
# {1: 'setosa', 2: 'versicolor', 3: 'virginica'}

# %% [markdown]
# #### Agregar una columna a un DataFrame

# %%
df['species'] = [esp[i] for i in df['species_id']]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species_id  \
# 0             5.1          3.5           1.4          0.2           1
# 1             4.9          3.0           1.4          0.2           1
# 2             4.7          3.2           1.3          0.2           1
# 3             4.6          3.1           1.5          0.2           1
# 4             5.0          3.6           1.4          0.2           1
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3           3
# 146           6.3          2.5           5.0          1.9           3
# 147           6.5          3.0           5.2          2.0           3
# 148           6.2          3.4           5.4          2.3           3
# 149           5.9          3.0           5.1          1.8           3
#
#        species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# #### convertir una columna en lista

# %%
df['sepal_length'].tolist()
# Out:
# [5.1,
#  4.9,
#  4.7,
#  4.6,
#  5.0,
#  5.4,
#  4.6,
#  5.0,
#  4.4,
#  4.9,
#  5.4,
#  4.8,
#  4.8,
#  4.3,
#  5.8,
#  5.7,
#  5.4,
#  5.1,
#  5.7,
#  5.1,
#  5.4,
#  5.1,
#  4.6,
#  5.1,
#  4.8,
#  5.0,
#  5.0,
#  5.2,
#  5.2,
#  4.7,
#  4.8,
#  5.4,
#  5.2,
#  5.5,
#  4.9,
#  5.0,
#  5.5,
#  4.9,
#  4.4,
#  5.1,
#  5.0,
#  4.5,
#  4.4,
#  5.0,
#  5.1,
#  4.8,
#  5.1,
#  4.6,
#  5.3,
#  5.0,
#  7.0,
#  6.4,
#  6.9,
#  5.5,
#  6.5,
#  5.7,
#  6.3,
#  4.9,
#  6.6,
#  5.2,
#  5.0,
#  5.9,
#  6.0,
#  6.1,
#  5.6,
#  6.7,
#  5.6,
#  5.8,
#  6.2,
#  5.6,
#  5.9,
#  6.1,
#  6.3,
#  6.1,
#  6.4,
#  6.6,
#  6.8,
#  6.7,
#  6.0,
#  5.7,
#  5.5,
#  5.5,
#  5.8,
#  6.0,
#  5.4,
#  6.0,
#  6.7,
#  6.3,
#  5.6,
#  5.5,
#  5.5,
#  6.1,
#  5.8,
#  5.0,
#  5.6,
#  5.7,
#  5.7,
#  6.2,
#  5.1,
#  5.7,
#  6.3,
#  5.8,
#  7.1,
#  6.3,
#  6.5,
#  7.6,
#  4.9,
#  7.3,
#  6.7,
#  7.2,
#  6.5,
#  6.4,
#  6.8,
#  5.7,
#  5.8,
#  6.4,
#  6.5,
#  7.7,
#  7.7,
#  6.0,
#  6.9,
#  5.6,
#  7.7,
#  6.3,
#  6.7,
#  7.2,
#  6.2,
#  6.1,
#  6.4,
#  7.2,
#  7.4,
#  7.9,
#  6.4,
#  6.3,
#  6.1,
#  7.7,
#  6.3,
#  6.4,
#  6.0,
#  6.9,
#  6.7,
#  6.9,
#  5.8,
#  6.8,
#  6.7,
#  6.7,
#  6.3,
#  6.5,
#  6.2,
#  5.9]

# %%
### Asignar colores a valores de la columna sepal_length

# %%
import matplotlib as mpl
import matplotlib.cm as cm
from matplotlib.colors import to_hex

# %% [markdown]
# #### debemos obtener el mínimo y máximo de la columna

# %%
minimo = min(df['sepal_length'].tolist())

# %%
maximo = max(df['sepal_length'].tolist())

# %%
minimo, maximo
# Out:
# (4.3, 7.9)

# %%
normlst = mpl.colors.Normalize(vmin=minimo, vmax=maximo, clip=True)
mapperlst = cm.ScalarMappable(norm=normlst, cmap=cm.Spectral) # cm.Spectral

# %%
colors = {}
for e, v in enumerate(df['sepal_length']):
    colors[v] = to_hex(mapperlst.to_rgba(v))

# %%
colors
# Out:
# {5.1: '#f67a49',
#  4.9: '#e95c47',
#  4.7: '#d8434e',
#  4.6: '#cb334d',
#  5.0: '#f26944',
#  5.4: '#fdb163',
#  4.4: '#ad1246',
#  4.8: '#e1504b',
#  4.3: '#9e0142',
#  5.8: '#fee593',
#  5.7: '#feda86',
#  5.2: '#f98e52',
#  5.5: '#fdbf6f',
#  4.5: '#bc2249',
#  5.3: '#fba05b',
#  7.0: '#89d0a4',
#  6.4: '#eaf79e',
#  6.9: '#9cd7a4',
#  6.5: '#dff299',
#  6.3: '#f1f9a9',
#  6.6: '#cfec9d',
#  5.9: '#feeda1',
#  6.0: '#fff6b0',
#  6.1: '#fffebe',
#  5.6: '#fecc7b',
#  6.7: '#bfe5a0',
#  6.2: '#f8fcb4',
#  6.8: '#aedea3',
#  7.1: '#74c7a5',
#  7.6: '#3a7eb8',
#  7.3: '#54aead',
#  7.2: '#62bda7',
#  7.7: '#466eb1',
#  7.4: '#459eb4',
#  7.9: '#5e4fa2'}

# %% [markdown]
# #### Agregar una columna de colores al dataframe anterior

# %%
'sepal_length'
# Out:
# 'sepal_length'

# %%
df['sl_colors'] = [colors[i] for i in df['sepal_length']]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species_id  \
# 0             5.1          3.5           1.4          0.2           1
# 1             4.9          3.0           1.4          0.2           1
# 2             4.7          3.2           1.3          0.2           1
# 3             4.6          3.1           1.5          0.2           1
# 4             5.0          3.6           1.4          0.2           1
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3           3
# 146           6.3          2.5           5.0          1.9           3
# 147           6.5          3.0           5.2          2.0           3
# 148           6.2          3.4           5.4          2.3           3
# 149           5.9          3.0           5.1          1.8           3
#
#        species sl_colors
# 0       setosa   #f67a49
# 1       setosa   #e95c47
# 2       setosa   #d8434e
# 3       setosa   #cb334d
# 4       setosa   #f26944
# ..         ...       ...
# 145  virginica   #bfe5a0
# 146  virginica   #f1f9a9
# 147  virginica   #dff299
# 148  virginica   #f8fcb4
# 149  virginica   #feeda1
#
# [150 rows x 7 columns]

# %%
sc = dict(zip(['setosa', 'versicolor', 'virginica'],
         ['red', 'royalablue', 'black']))

# %%
df['spe_col'] = [sc[i] for i in df['species']]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species_id  \
# 0             5.1          3.5           1.4          0.2           1
# 1             4.9          3.0           1.4          0.2           1
# 2             4.7          3.2           1.3          0.2           1
# 3             4.6          3.1           1.5          0.2           1
# 4             5.0          3.6           1.4          0.2           1
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3           3
# 146           6.3          2.5           5.0          1.9           3
# 147           6.5          3.0           5.2          2.0           3
# 148           6.2          3.4           5.4          2.3           3
# 149           5.9          3.0           5.1          1.8           3
#
#        species sl_colors spe_col
# 0       setosa   #f67a49     red
# 1       setosa   #e95c47     red
# 2       setosa   #d8434e     red
# 3       setosa   #cb334d     red
# 4       setosa   #f26944     red
# ..         ...       ...     ...
# 145  virginica   #bfe5a0   black
# 146  virginica   #f1f9a9   black
# 147  virginica   #dff299   black
# 148  virginica   #f8fcb4   black
# 149  virginica   #feeda1   black
#
# [150 rows x 8 columns]

# %% [markdown]
# #### Tablas dinámicas

# %%
pd.pivot_table(df, values = 'sepal_length', 
               index = 'species', aggfunc = sum)
# Out:
#             sepal_length
# species
# setosa             250.3
# versicolor         296.8
# virginica          329.4

# %%
pd.pivot_table(df, values = 'sepal_length', 
               index = ['species'], aggfunc = len)
# Out:
#             sepal_length
# species
# setosa              50.0
# versicolor          50.0
# virginica           50.0

# %%
pd.pivot_table(df, values = ['sepal_length', 'sepal_width'], 
               index = ['species'], aggfunc = np.mean)
# Out:
#             sepal_length  sepal_width
# species
# setosa             5.006        3.418
# versicolor         5.936        2.770
# virginica          6.588        2.974

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species_id', 'species', 'sl_colors', 'spe_col'],
#       dtype='object')

# %%
pd.pivot_table(df, values = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], 
               index = ['species'], aggfunc = np.std)
# Out:
#             petal_length  petal_width  sepal_length  sepal_width
# species
# setosa          0.173511     0.107210      0.352490     0.381024
# versicolor      0.469911     0.197753      0.516171     0.313798
# virginica       0.551895     0.274650      0.635880     0.322497

# %% [markdown]
# ## <font color = royalblue>DataFrame</font>
#
# https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
df.style.bar(subset=['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], color='royalblue')
# Out:
# <style  type="text/css" >
#     #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 22.2%, transparent 22.2%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 62.5%, transparent 62.5%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 6.8%, transparent 6.8%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 4.2%, transparent 4.2%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 16.7%, transparent 16.7%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 41.7%, transparent 41.7%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 6.8%, transparent 6.8%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 4.2%, transparent 4.2%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 11.1%, transparent 11.1%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 50.0%, transparent 50.0%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 5.1%, transparent 5.1%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 4.2%, transparent 4.2%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 8.3%, transparent 8.3%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 45.8%, transparent 45.8%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 8.5%, transparent 8.5%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 4.2%, transparent 4.2%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 19.4%, transparent 19.4%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 66.7%, transparent 66.7%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 6.8%, transparent 6.8%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 4.2%, transparent 4.2%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 30.6%, transparent 30.6%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 79.2%, transparent 79.2%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 11.9%, transparent 11.9%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 12.5%, transparent 12.5%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 8.3%, transparent 8.3%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 58.3%, transparent 58.3%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 6.8%, transparent 6.8%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 8.3%, transparent 8.3%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 19.4%, transparent 19.4%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 58.3%, transparent 58.3%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 8.5%, transparent 8.5%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow7_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 4.2%, transparent 4.2%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 2.8%, transparent 2.8%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 37.5%, transparent 37.5%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 6.8%, transparent 6.8%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow8_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 4.2%, transparent 4.2%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 16.7%, transparent 16.7%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 45.8%, transparent 45.8%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,royalblue 8.5%, transparent 8.5%);
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow9_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_8ddef67e_9d5b_11ef_9b24_f4c88a728a6brow10_col0 {

# %%
from itables import show

# %%
show(df)
# Out:
# <div><table id="03039cf8-ee2e-436a-9738-f1e981d85fcd" class="display"><thead>
#     <tr style="text-align: right;">
#
#       <th>sepal_length</th>
#       <th>sepal_width</th>
#       <th>petal_length</th>
#       <th>petal_width</th>
#       <th>species_id</th>
#       <th>species</th>
#       <th>sl_colors</th>
#       <th>spe_col</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         var dt_args = {"columnDefs": [{"width": "70px", "targets": "_all"}], "data": [[5.1, 3.5, 1.4, 0.2, 1, "setosa", "#f67a49", "red"], [4.9, 3.0, 1.4, 0.2, 1, "setosa", "#e95c47", "red"], [4.7, 3.2, 1.3, 0.2, 1, "setosa", "#d8434e", "red"], [4.6, 3.1, 1.5, 0.2, 1, "setosa", "#cb334d", "red"], [5.0, 3.6, 1.4, 0.2, 1, "setosa", "#f26944", "red"], [5.4, 3.9, 1.7, 0.4, 1, "setosa", "#fdb163", "red"], [4.6, 3.4, 1.4, 0.3, 1, "setosa", "#cb334d", "red"], [5.0, 3.4, 1.5, 0.2, 1, "setosa", "#f26944", "red"], [4.4, 2.9, 1.4, 0.2, 1, "setosa", "#ad1246", "red"], [4.9, 3.1, 1.5, 0.1, 1, "setosa", "#e95c47", "red"], [5.4, 3.7, 1.5, 0.2, 1, "setosa", "#fdb163", "red"], [4.8, 3.4, 1.6, 0.2, 1, "setosa", "#e1504b", "red"], [4.8, 3.0, 1.4, 0.1, 1, "setosa", "#e1504b", "red"], [4.3, 3.0, 1.1, 0.1, 1, "setosa", "#9e0142", "red"], [5.8, 4.0, 1.2, 0.2, 1, "setosa", "#fee593", "red"], [5.7, 4.4, 1.5, 0.4, 1, "setosa", "#feda86", "red"], [5.4, 3.9, 1.3, 0.4, 1, "setosa", "#fdb163", "red"], [5.1, 3.5, 1.4, 0.3, 1, "setosa", "#f67a49", "red"], [5.7, 3.8, 1.7, 0.3, 1, "setosa", "#feda86", "red"], [5.1, 3.8, 1.5, 0.3, 1, "setosa", "#f67a49", "red"], [5.4, 3.4, 1.7, 0.2, 1, "setosa", "#fdb163", "red"], [5.1, 3.7, 1.5, 0.4, 1, "setosa", "#f67a49", "red"], [4.6, 3.6, 1.0, 0.2, 1, "setosa", "#cb334d", "red"], [5.1, 3.3, 1.7, 0.5, 1, "setosa", "#f67a49", "red"], [4.8, 3.4, 1.9, 0.2, 1, "setosa", "#e1504b", "red"], [5.0, 3.0, 1.6, 0.2, 1, "setosa", "#f26944", "red"], [5.0, 3.4, 1.6, 0.4, 1, "setosa", "#f26944", "red"], [5.2, 3.5, 1.5, 0.2, 1, "setosa", "#f98e52", "red"], [5.2, 3.4, 1.4, 0.2, 1, "setosa", "#f98e52", "red"], [4.7, 3.2, 1.6, 0.2, 1, "setosa", "#d8434e", "red"], [4.8, 3.1, 1.6, 0.2, 1, "setosa", "#e1504b", "red"], [5.4, 3.4, 1.5, 0.4, 1, "setosa", "#fdb163", "red"], [5.2, 4.1, 1.5, 0.1, 1, "setosa", "#f98e52", "red"], [5.5, 4.2, 1.4, 0.2, 1, "setosa", "#fdbf6f", "red"], [4.9, 3.1, 1.5, 0.1, 1, "setosa", "#e95c47", "red"], [5.0, 3.2, 1.2, 0.2, 1, "setosa", "#f26944", "red"], [5.5, 3.5, 1.3, 0.2, 1, "setosa", "#fdbf6f", "red"], [4.9, 3.1, 1.5, 0.1, 1, "setosa", "#e95c47", "red"], [4.4, 3.0, 1.3, 0.2, 1, "setosa", "#ad1246", "red"], [5.1, 3.4, 1.5, 0.2, 1, "setosa", "#f67a49", "red"], [5.0, 3.5, 1.3, 0.3, 1, "setosa", "#f26944", "red"], [4.5, 2.3, 1.3, 0.3, 1, "setosa", "#bc2249", "red"], [4.4, 3.2, 1.3, 0.2, 1, "setosa", "#ad1246", "red"], [5.0, 3.5, 1.6, 0.6, 1, "setosa", "#f26944", "red"], [5.1, 3.8, 1.9, 0.4, 1, "setosa", "#f67a49", "red"], [4.8, 3.0, 1.4, 0.3, 1, "setosa", "#e1504b", "red"], [5.1, 3.8, 1.6, 0.2, 1, "setosa", "#f67a49", "red"], [4.6, 3.2, 1.4, 0.2, 1, "setosa", "#cb334d", "red"], [5.3, 3.7, 1.5, 0.2, 1, "setosa", "#fba05b", "red"], [5.0, 3.3, 1.4, 0.2, 1, "setosa", "#f26944", "red"], [7.0, 3.2, 4.7, 1.4, 2, "versicolor", "#89d0a4", "royalablue"], [6.4, 3.2, 4.5, 1.5, 2, "versicolor", "#eaf79e", "royalablue"], [6.9, 3.1, 4.9, 1.5, 2, "versicolor", "#9cd7a4", "royalablue"], [5.5, 2.3, 4.0, 1.3, 2, "versicolor", "#fdbf6f", "royalablue"], [6.5, 2.8, 4.6, 1.5, 2, "versicolor", "#dff299", "royalablue"], [5.7, 2.8, 4.5, 1.3, 2, "versicolor", "#feda86", "royalablue"], [6.3, 3.3, 4.7, 1.6, 2, "versicolor", "#f1f9a9", "royalablue"], [4.9, 2.4, 3.3, 1.0, 2, "versicolor", "#e95c47", "royalablue"], [6.6, 2.9, 4.6, 1.3, 2, "versicolor", "#cfec9d", "royalablue"], [5.2, 2.7, 3.9, 1.4, 2, "versicolor", "#f98e52", "royalablue"], [5.0, 2.0, 3.5, 1.0, 2, "versicolor", "#f26944", "royalablue"], [5.9, 3.0, 4.2, 1.5, 2, "versicolor", "#feeda1", "royalablue"], [6.0, 2.2, 4.0, 1.0, 2, "versicolor", "#fff6b0", "royalablue"], [6.1, 2.9, 4.7, 1.4, 2, "versicolor", "#fffebe", "royalablue"], [5.6, 2.9, 3.6, 1.3, 2, "versicolor", "#fecc7b", "royalablue"], [6.7, 3.1, 4.4, 1.4, 2, "versicolor", "#bfe5a0", "royalablue"], [5.6, 3.0, 4.5, 1.5, 2, "versicolor", "#fecc7b", "royalablue"], [5.8, 2.7, 4.1, 1.0, 2, "versicolor", "#fee593", "royalablue"], [6.2, 2.2, 4.5, 1.5, 2, "versicolor", "#f8fcb4", "royalablue"], [5.6, 2.5, 3.9, 1.1, 2, "versicolor", "#fecc7b", ...

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species_id', 'species', 'sl_colors', 'spe_col'],
#       dtype='object')

# %%
df2 = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].corr()

# %%
df2.style.background_gradient(cmap = 'Spectral')
# Out:
# <style  type="text/css" >
#     #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow0_col0 {
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow0_col1 {
#             background-color:  #f67a49;
#             color:  #000000;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow0_col2 {
#             background-color:  #3682ba;
#             color:  #000000;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow0_col3 {
#             background-color:  #439bb5;
#             color:  #000000;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow0_col4 {
#             background-color:  #4ea7b0;
#             color:  #000000;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow1_col0 {
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow1_col1 {
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow1_col2 {
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow1_col3 {
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow1_col4 {
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow2_col0 {
#             background-color:  #3990ba;
#             color:  #000000;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow2_col1 {
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow2_col2 {
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow2_col3 {
#             background-color:  #525fa9;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow2_col4 {
#             background-color:  #4e63ac;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow3_col0 {
#             background-color:  #54aead;
#             color:  #000000;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow3_col1 {
#             background-color:  #b61b48;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow3_col2 {
#             background-color:  #545ca8;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow3_col3 {
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow3_col4 {
#             background-color:  #525fa9;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow4_col0 {
#             background-color:  #64c0a6;
#             color:  #000000;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow4_col1 {
#             background-color:  #9e0142;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow4_col2 {
#             background-color:  #4e63ac;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow4_col3 {
#             background-color:  #5061aa;
#             color:  #f1f1f1;
#         }    #T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow4_col4 {
#             background-color:  #5e4fa2;
#             color:  #f1f1f1;
#         }</style><table id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal_length</th>        <th class="col_heading level0 col1" >sepal_width</th>        <th class="col_heading level0 col2" >petal_length</th>        <th class="col_heading level0 col3" >petal_width</th>        <th class="col_heading level0 col4" >species_id</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6blevel0_row0" class="row_heading level0 row0" >sepal_length</th>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow0_col1" class="data row0 col1" >-0.109369</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow0_col2" class="data row0 col2" >0.871754</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow0_col3" class="data row0 col3" >0.817954</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow0_col4" class="data row0 col4" >0.782561</td>
#             </tr>
#             <tr>
#                         <th id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6blevel0_row1" class="row_heading level0 row1" >sepal_width</th>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow1_col0" class="data row1 col0" >-0.109369</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow1_col2" class="data row1 col2" >-0.420516</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow1_col3" class="data row1 col3" >-0.356544</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow1_col4" class="data row1 col4" >-0.419446</td>
#             </tr>
#             <tr>
#                         <th id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6blevel0_row2" class="row_heading level0 row2" >petal_length</th>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow2_col0" class="data row2 col0" >0.871754</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow2_col1" class="data row2 col1" >-0.420516</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow2_col3" class="data row2 col3" >0.962757</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow2_col4" class="data row2 col4" >0.949043</td>
#             </tr>
#             <tr>
#                         <th id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6blevel0_row3" class="row_heading level0 row3" >petal_width</th>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow3_col0" class="data row3 col0" >0.817954</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow3_col1" class="data row3 col1" >-0.356544</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow3_col2" class="data row3 col2" >0.962757</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow3_col4" class="data row3 col4" >0.956464</td>
#             </tr>
#             <tr>
#                         <th id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6blevel0_row4" class="row_heading level0 row4" >species_id</th>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow4_col0" class="data row4 col0" >0.782561</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow4_col1" class="data row4 col1" >-0.419446</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow4_col2" class="data row4 col2" >0.949043</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow4_col3" class="data row4 col3" >0.956464</td>
#                         <td id="T_11497eb0_9d5c_11ef_9173_f4c88a728a6brow4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
df2.style.background_gradient(cmap = 'Reds')
# Out:
# <style  type="text/css" >
#     #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow0_col1 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow0_col2 {
#             background-color:  #940b13;
#             color:  #f1f1f1;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow0_col3 {
#             background-color:  #a81016;
#             color:  #f1f1f1;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow1_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow1_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow1_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow2_col0 {
#             background-color:  #9f0e14;
#             color:  #f1f1f1;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow2_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow2_col3 {
#             background-color:  #75030f;
#             color:  #f1f1f1;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow3_col0 {
#             background-color:  #b11218;
#             color:  #f1f1f1;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow3_col1 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow3_col2 {
#             background-color:  #73030f;
#             color:  #f1f1f1;
#         }    #T_d914e276_9d5c_11ef_b917_f4c88a728a6brow3_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_d914e276_9d5c_11ef_b917_f4c88a728a6b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal_length</th>        <th class="col_heading level0 col1" >sepal_width</th>        <th class="col_heading level0 col2" >petal_length</th>        <th class="col_heading level0 col3" >petal_width</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d914e276_9d5c_11ef_b917_f4c88a728a6blevel0_row0" class="row_heading level0 row0" >sepal_length</th>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow0_col1" class="data row0 col1" >-0.109369</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow0_col2" class="data row0 col2" >0.871754</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow0_col3" class="data row0 col3" >0.817954</td>
#             </tr>
#             <tr>
#                         <th id="T_d914e276_9d5c_11ef_b917_f4c88a728a6blevel0_row1" class="row_heading level0 row1" >sepal_width</th>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow1_col0" class="data row1 col0" >-0.109369</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow1_col2" class="data row1 col2" >-0.420516</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow1_col3" class="data row1 col3" >-0.356544</td>
#             </tr>
#             <tr>
#                         <th id="T_d914e276_9d5c_11ef_b917_f4c88a728a6blevel0_row2" class="row_heading level0 row2" >petal_length</th>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow2_col0" class="data row2 col0" >0.871754</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow2_col1" class="data row2 col1" >-0.420516</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow2_col3" class="data row2 col3" >0.962757</td>
#             </tr>
#             <tr>
#                         <th id="T_d914e276_9d5c_11ef_b917_f4c88a728a6blevel0_row3" class="row_heading level0 row3" >petal_width</th>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow3_col0" class="data row3 col0" >0.817954</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow3_col1" class="data row3 col1" >-0.356544</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow3_col2" class="data row3 col2" >0.962757</td>
#                         <td id="T_d914e276_9d5c_11ef_b917_f4c88a728a6brow3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # <font color = royalblue>Integración de la estructura del lenguaje para la gestión de datos.</font>

# %% [markdown]
# #### <font color = red> Ejercicios integrando todas las estructuras</font>

# %%
df

# %% [markdown]
# ##### A partir  del df anterior construir un diccionario usando la columna `species` para claves y la columna `petal_length` para valores

# %% [markdown]
# ##### Convertir la lista de tuplas en diccinoario

# %%
inter = [('A', 1), ('A' ,3),
         ('B' ,3), ('B' ,1), ('B' ,5), ('B' ,4),
         ('C' ,4), ('C' ,3), ('C' ,7), ('C' ,8),
         ('D' ,2), ('D' ,8), ('D' ,7), ('D' ,9)]

# %%
[]

# %%
# output
{'C': {3, 4, 7, 8}, 'D': {2, 7, 8, 9}, 'B': {1, 3, 4, 5}, 'A': {1, 3}}

# %% [markdown]
# ##### Convertir un diccionario a una lista

# %% [markdown]
# # <font color = royalblue> Visualizaciones usando Matplotlib. </font>
#
# ##### [Writing mathematical expressions](https://matplotlib.org/stable/users/explain/text/mathtext.html#mathtext)
#
# ##### [COLORMAPS](https://matplotlib.org/stable/users/explain/colors/colormaps.html)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##### area del grafico

# %%
fig = plt.figure(figsize=(5, 5))

ax = fig.add_axes([0, 0, 1, 1])

ax.set_facecolor('tan')

plt.close()
fig

# %% [markdown]
# ##### cuadrícula

# %%
fig = plt.figure(figsize=(5, 5))

ax = fig.add_axes([0, 0, 1, 1])

ax.set_facecolor('none')

ax.grid(color = "black", which = "both",
        linewidth = 7, alpha = 0.5, zorder = 0)

plt.close()
fig

# %% [markdown]
# ##### elimina los bordes, algunos graficos lo requieren

# %%
fig = plt.figure(figsize=(5, 5))

ax = fig.add_axes([0, 0, 1, 1])

ax.set_facecolor('none')

ax.axis('off') # 'off', 'on'

plt.close()
fig

# %% [markdown]
# ##### Inset Plots

# %%
fig = plt.figure(figsize=(5, 5))

ax = fig.add_axes([0, 0, 1, 1])

ax.set_facecolor('gold')

ax1 = fig.add_axes([0.1, 0.1, 0.5, 0.3])

ax1.set_facecolor('limegreen')


plt.close()
fig

# %% [markdown]
# ##### titulos en los ejes

# %%
etiquetax = 'Tiempo ${(seg)}$'

# %%
fig = plt.figure(figsize=(3, 3))

ax = fig.add_axes([0, 0, 1, 1])

ax.set_facecolor('silver')

ax.set_xlabel(etiquetax, fontsize = 15)

ax.set_ylabel('Eje Y ${(m)}$', fontsize = 15)

plt.close()
fig

# %% [markdown]
# ##### limites de los ejes

# %%
fig = plt.figure(figsize=(5, 5))

ax = fig.add_axes([0, 0, 1, 1])

ax.set_xlim(0, 3)

ax.set_ylim(3, 10)

ax.set_facecolor('none')

ax.set_xlabel('Eje X', fontsize = 15)

ax.set_ylabel('Eje Y', fontsize = 15)

plt.close()
fig

# %% [markdown]
# ##### edicion de los ejes

# %%
fig = plt.figure(figsize=(5, 5))

ax = fig.add_axes([0, 0, 1, 1])

ax.set_xlim(0, 3)

ax.set_ylim(0, 1)

ax.set_facecolor('none')

ax.set_xlabel('Eje X', fontsize = 15)

ax.set_ylabel('Eje Y', fontsize = 15)

ax.set_xticks([0, 1, 2, 3])

ax.set_xticklabels(['', 'Grupo A', 'Grupo B', ''], rotation = 0, fontsize = 15)

ax.set_yticks([0, 0.75, 1])

ax.set_yticklabels(['0', '0.75', '1'], rotation = 0, fontsize = 15)

plt.close()
fig

# %% [markdown]
# ### <font color = blue> Scatter plot
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.scatter.html
#
# '.', 'o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X'

# %%
fig = plt.figure(figsize=(3, 3))

ax = fig.add_axes([0, 0, 1, 1])
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
ax.set_facecolor('none')

ax.set_xlabel('Eje X', fontsize = 15)
ax.set_ylabel('Eje Y', fontsize = 15)

for i in [0.5, 1, 1.5, 2, 2.5]:
    ax.scatter(i, i, s = 300, facecolor = 'blue', lw = 0,
              marker = 'v')


plt.close()
fig

# %% [markdown]
# #### control de los bordes en los puntos

# %%
fig = plt.figure(figsize=(3, 3))

ax = fig.add_axes([0, 0, 1, 1])
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
ax.set_xlabel('Eje X', fontsize = 15)
ax.set_ylabel('Eje Y', fontsize = 15)

for i in [0.5, 1, 1.5, 2, 2.5]:
    ax.scatter(i, i, s = 200, facecolor = 'gold', 
               edgecolor = 'black', lw = 2)

plt.close()
fig

# %% [markdown]
# #### asignar diferentes colores a los puntos de forma iterada
# ##### Usar alguna de las siguientes listas:
#
# `tab10 = [mpl.colors.to_hex(i) for i in cm.tab10(np.arange(10)/10.)]`
#
# `tab20 = [matplotlib.colors.to_hex(i) for i in cm.tab20(np.arange(20)/20.)]`
#
# `Set3 = [matplotlib.colors.to_hex(i) for i in cm.Set3(np.arange(12)/12.)]`
#
# `Set2 = [matplotlib.colors.to_hex(i) for i in cm.Set2(np.arange(8)/8.)]`
#
# `Set1 = [matplotlib.colors.to_hex(i) for i in cm.Set1(np.arange(9)/9.)]`
#
# `Pastel2 = [matplotlib.colors.to_hex(i) for i in cm.Pastel2(np.arange(8)/8.)]`
#
# `Dark2 = [matplotlib.colors.to_hex(i) for i in cm.Dark2(np.arange(8)/8.)]`
#
# `Paired = [matplotlib.colors.to_hex(i) for i in cm.Paired(np.arange(12)/12.)]`

# %%
tab10 = [mpl.colors.to_hex(i) for i in cm.tab10(np.arange(10)/10.)]

# %%
tab10
# Out:
# ['#1f77b4',
#  '#ff7f0e',
#  '#2ca02c',
#  '#d62728',
#  '#9467bd',
#  '#8c564b',
#  '#e377c2',
#  '#7f7f7f',
#  '#bcbd22',
#  '#17becf']

# %%
fig = plt.figure(figsize=(3, 3))

ax = fig.add_axes([0, 0, 1, 1])
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
ax.set_xlabel('Eje X', fontsize = 15)
ax.set_ylabel('Eje Y', fontsize = 15)

for i, c in zip([0.5, 1, 1.5, 2, 2.5], tab10):
    ax.scatter(i, i, s = i * 100, facecolor = c, 
               edgecolor = 'black', lw = 0)

plt.close()
fig

# %% [markdown]
# #### asignar etiquetas (texto) a los puntos

# %%
fig = plt.figure(figsize=(3, 3))

ax = fig.add_axes([0, 0, 1, 1])
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
ax.set_xlabel('Eje X', fontsize = 15)
ax.set_ylabel('Eje Y', fontsize = 15)

for i, c in zip([0.5, 1, 1.5, 2, 2.5], tab10):
    ax.scatter(i, i, s = i * 100, facecolor = c, 
               edgecolor = 'black', lw = 0)
    ax.text(i, i, '  '+c, ha = 'left', va = 'center', fontsize = 15)
    
plt.close()
fig

# %% [markdown]
# #### Al plot anterior agregar una leyenda personalizada

# %% [markdown]
# #### <font color = red>A partir del dataframe de Iris crear un Scatter plot</font>
#
# ##### Agrega colores a cada punto

# %%
# etiquetas
ejex_etiq = 'sepal_length'
ejey_etiq = 'petal_length'
ejex = df[ejex_etiq] 
ejey = df[ejey_etiq]

# %%
fig = plt.figure(figsize=(3, 3))

ax = fig.add_axes([0, 0, 1, 1])
ax.set_xlabel('Eje X', fontsize = 15)
ax.set_ylabel('Eje Y', fontsize = 15)

for x, y, s in zip(ejex, ejey, df['species']):
    ax.scatter(x, y, s = np.mean([x, y]) * 30, facecolor = sc[s], 
               edgecolor = 'black', lw = 0, alpha = 0.5)
ax1 = fig.add_axes([1.05, 0.5, 0.5, 0.5])
ax1.set_xlim(0, 1)
ax1.set_ylim(0, 1)
N = 0.7
for c in sc:
    ax1.text(0.2, N, c, fontsize = 13, ha = 'left', va = 'center',
            color = sc[c])
    ax1.scatter(0.1, N, s = 100, c = sc[c], alpha = 0.5)
    N -= 0.2
ax1.axis('off')
ax1.text(0.1, 0.9, 'Species', fontsize = 13, ha = 'left', va = 'center')
plt.close()
fig

# %%
s
# Out:
# 'versicolor'

# %%
sc.update({'versicolor': 'royalblue'})

# %%
sc
# Out:
# {'setosa': 'red', 'versicolor': 'royalblue', 'virginica': 'black'}

# %% [markdown]
# ##### <font color = red>inset plot: seleccionar un rango de puntos</font>

# %%
x1, x2, y1, y2 = 5.5, 7, 4, 6

# %%
fig = plt.figure(figsize=(6, 6))

ax = fig.add_axes([0, 0, 1, 1])
ax.set_facecolor('none')

xmin, xmax = 4, 10
ax.set_xlim(xmin, xmax)

ymin, ymax = 0, 7.5
ax.set_ylim(ymin, ymax)

ax.set_xlabel(ejex_etiq, fontsize = 15)

ax.set_ylabel(ejey_etiq, fontsize = 15)

U = ax.scatter(ejex, ejey, s = 70, c = 'royalblue', edgecolor = 'black', lw = 0)

#x1, x2, y1, y2 = 5.5, 7, 4, 6

A = [x1, x1], [y1, y2]
ax.plot(A[0], A[1], color = 'black', lw = 1) # A

B = [x1, x2], [y2, y2]
ax.plot(B[0], B[1], color = 'black', lw = 1) # B

C = [x2, x2], [y1, y2]
ax.plot(C[0], C[1], color = 'black', lw = 1) # C

D = [x1, x2], [y1, y1]
ax.plot(D[0], D[1], color = 'black', lw = 1) # D


X1, Y1, X2, Y2 = 0.55, 0.07, 0.4, 0.4

ax.plot([x1, xmin + (xmax-xmin) * (X1)], [y1, ymax * (Y1)], color = 'black', lw = 1)
ax.plot([x2, xmin + (xmax-xmin) * (X1 + X2)], [y2, ymax * (Y1 + Y2)], color = 'black', lw = 1)

ax1 = fig.add_axes([X1, Y1, X2, Y2])
ax1.set_facecolor('none')

selx, sely = [], []
for x, y in zip(ejex, ejey):
    if x1 < x < x2:
        if y1 < y < y2:
            selx.append(x)
            sely.append(y)
            
ax1.set_xlim(x1, x2)
ax1.set_ylim(y1, y2)    

ax1.scatter(selx, sely, s = 70, c = 'royalblue', edgecolor = 'black', lw = 0)


ax1.set_yticks(list(range(y1, y2 + 1)))
ax1.set_yticklabels([str(i) for i in list(range(y1, y2 + 1))], rotation = 0, fontsize = 10)

plt.close()

# %%
fig

# %% [markdown]
# # <font color = royalblue>Gráficos personalizados</font>
#
# ### <font color = red>Ejercicio</font>
#
# #### A partir  de la tabla `Enrichment.txt` realizar lo siguiente:
#
# ##### 1) Filtrar la tabla a un FDR < 0.05
# ##### 2) Hacer un scatter plot usando la columna Term como eje Y y el -log10(FDR) como eje X.
# ##### 3) Agregar como atributo datos de la columna list_count
# ##### 4) Asignar colores a cada uno de los puntos.
# ##### 5) Agregar una la leyenda de escala de tamaños de puntos
